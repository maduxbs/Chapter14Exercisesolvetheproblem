# %% [markdown]
# ## 1 Ex.

# %% [markdown]
# l will give your code as example any exactly this detail! Hope this make clarification the structure for a code.

# %%
import sqlite3

def create_cities_db():
    conn = sqlite3.connect('cities.db')
    cursor = conn.cursor()

    # Create 'cities' table if not exists
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS cities (
            CityName TEXT,
            Population INTEGER
        )
    ''')

    # Insert sample data (adjust as needed)
    cities_data = [
        ('New York', 8419600),
        ('Los Angeles', 3999759),
        ('Chicago', 2716000),
        ('Houston', 2328046),
        ('Phoenix', 1680992),
        ('Philadelphia', 1584064),
        ('San Antonio', 1547253),
        ('San Diego', 1423851),
        ('Dallas', 1343573),
        ('San Jose', 1030119),
    ]
    
    cursor.executemany('INSERT INTO cities (CityName, Population) VALUES (?, ?)', cities_data)

    # Commit changes and close connection
    conn.commit()
    conn.close()

def display_cities_sorted_by_population(ascending=True):
    conn = sqlite3.connect('cities.db')
    cursor = conn.cursor()

    order_by = 'ASC' if ascending else 'DESC'
    query = f"SELECT * FROM cities ORDER BY Population {order_by};"

    cursor.execute(query)
    cities = cursor.fetchall()

    print("Cities sorted by population:")
    for city in cities:
        print(city)

    conn.close()

# Create the 'cities.db' database and populate it with sample data
create_cities_db()

# Display cities sorted by population in ascending order
display_cities_sorted_by_population(ascending=True)

    
import sqlite3

def create_cities_db():
    conn = sqlite3.connect('cities.db')
    cursor = conn.cursor()

    # Create 'cities' table if not exists
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS cities (
            CityName TEXT,
            Population INTEGER
        )
    ''')

    # Insert sample data (adjust as needed)
    cities_data = [
        ('New York', 8419600),
        ('Los Angeles', 3999759),
        ('Chicago', 2716000),
        ('Houston', 2328046),
        ('Phoenix', 1680992),
        ('Philadelphia', 1584064),
        ('San Antonio', 1547253),
        ('San Diego', 1423851),
        ('Dallas', 1343573),
        ('San Jose', 1030119),
    ]
    
    cursor.executemany('INSERT INTO cities (CityName, Population) VALUES (?, ?)', cities_data)

    # Commit changes and close connection
    conn.commit()
    conn.close()

def display_cities_sorted_by_name():
    conn = sqlite3.connect('cities.db')
    cursor = conn.cursor()
    
    query = "SELECT * FROM cities ORDER BY CityName;"
    
    cursor.execute(query)
    cities = cursor.fetchall()
    
    print("Cities sorted by name:")
    for city in cities:
        print(city)
        
    conn.close()

# Create the 'cities.db' database and populate it with sample data
create_cities_db()

# Display cities sorted by name
display_cities_sorted_by_name()

    
def display_total_population():
    conn = sqlite3. connect('cities.db')
    cursor = conn.cursor()
    
    query = "SELECT SUM(Population) FROM cities;"
    
    cursor.execute(query)
    total_population = cursor.fetchone()[0]
    
    print(f"Total population of all cities: {total_population}")
    
    conn.close()
    
import sqlite3

def create_cities_db():
    conn = sqlite3.connect('cities.db')
    cursor = conn.cursor()

    # Create 'cities' table if not exists
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS cities (
            CityName TEXT,
            Population INTEGER
        )
    ''')

    # Insert sample data (adjust as needed)
    cities_data = [
        ('New York', 8419600),
        ('Los Angeles', 3999759),
        ('Chicago', 2716000),
        ('Houston', 2328046),
        ('Phoenix', 1680992),
        ('Philadelphia', 1584064),
        ('San Antonio', 1547253),
        ('San Diego', 1423851),
        ('Dallas', 1343573),
        ('San Jose', 1030119),
    ]
    
    cursor.executemany('INSERT INTO cities (CityName, Population) VALUES (?, ?)', cities_data)

    # Commit changes and close connection
    conn.commit()
    conn.close()

def display_total_population():
    conn = sqlite3.connect('cities.db')
    cursor = conn.cursor()
    
    query = "SELECT SUM(Population) FROM cities;"
    
    cursor.execute(query)
    total_population = cursor.fetchone()[0]
    
    print(f"Total population of all cities: {total_population}")
    
    conn.close()

def display_average_population():
    conn = sqlite3.connect('cities.db')
    cursor = conn.cursor()
    
    query = "SELECT AVG(Population) FROM cities;"
    
    cursor.execute(query)
    average_population = cursor.fetchone()[0]
    
    print(f"Average population of all cities: {average_population}")
    
    conn.close()

# Create the 'cities.db' database and populate it with sample data
create_cities_db()

# Display total population of all cities
display_total_population()

# Display average population of all cities
display_average_population()

def display_city_with_highest_population():
    conn = sqlite3.connect('cities.db')
    cursor = conn.cursor()
    
    query = "SELECT * FROM cities ORDER BY Population DESC LIMIT 1;"
    
    cursor.execute(query)
    city = cursor.fetchone()
    
    print(f"City with the highest population: {city}")
    
    conn.close()
    
def display_city_with_lowest_population():
    conn = sqlite3.connect('city.db')
    cursor = conn.cursor()
    
    query = "SELECT * FROM cities ORDER BY Population ASC LIMIT 1;"
    
    cursor.execute(query)
    city = cursor.fetchone()
    
    print(f"City with the lowest population: {city}")
    conn.close()
    
if __name__ == "__main__":
    create_cities_db()
    
    while True:
        print("\nOptions:")
        print("1. Display a list of cities sorted by population, in ascending order.")
        print("2. Display a list of cities sorted by population, in descending order.")
        print("3. Display a list of cities sorted by name.")
        print("4. Display the total population of all the cities.")
        print("5. Display the average population of all the cities.")
        print("6. Display the city with the highest population.")
        print("7. Display the city with the lowest population.")
        print("8. Exit")
        
        choice = input("Enter your choice (1-8):")
        
        if choice == '1':
            display_cities_sorted_by_population(ascending=True)
        elif choice == '2':
            display_cities_sorted_by_population(ascending=False)
        elif choice == '3':
            display_cities_sorted_by_name()
        elif choice == '4':
            display_total_population()
        elif choice == '5':
            display_average_population()
        elif choice == "6":
            display_city_with_highest_population()
        elif choice == "7":
            display_city_with_lowest_population()
        elif choice == '8':
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 8.")
# Out:
# Cities sorted by population:
# ('San Jose', 1030119)
# ('San Jose', 1030119)
# ('Dallas', 1343573)
# ('Dallas', 1343573)
# ('San Diego', 1423851)
# ('San Diego', 1423851)
# ('San Antonio', 1547253)
# ('San Antonio', 1547253)
# ('Philadelphia', 1584064)
# ('Philadelphia', 1584064)
# ('Phoenix', 1680992)
# ('Phoenix', 1680992)
# ('Houston', 2328046)
# ('Houston', 2328046)
# ('Chicago', 2716000)
# ('Chicago', 2716000)
# ('Los Angeles', 3999759)
# ('Los Angeles', 3999759)
# ('New York', 8419600)
# ('New York', 8419600)
# Cities sorted by name:
# ('Chicago', 2716000)
# ('Chicago', 2716000)
# ('Chicago', 2716000)
# ('Dallas', 1343573)
# ('Dallas', 1343573)
# ('Dallas', 1343573)
# ('Houston', 2328046)
# ('Houston', 2328046)
# ('Houston', 2328046)
# ('Los Angeles', 3999759)
# ('Los Angeles', 3999759)
# ('Los Angeles', 3999759)
# ('New York', 8419600)
# ('New York', 8419600)
# ('New York', 8419600)
# ('Philadelphia', 1584064)
# ('Philadelphia', 1584064)
# ('Philadelphia', 1584064)
# ...

# %% [markdown]
# 1. Create Database and Populate Data:
#    The'create_cities_db' function is a placeholder for the code responsible for creating an SQLite database named 'cities.db' and populating it with data. This function should include SQL commands to create a table, define its columns (such as CityName and Population), and inset data into the table.
#
# 2. Display Cities Sorted By Population:
#    The'display_cities_sorted_by_population'function connects to the database and executes an SQL query to fetch all cities from the 'cities' table. The query includes an ORDER BY clause to sort the cities either in ascending or descending order based on their population. The function then prints the sorted list of cities.
#
# 3. Display Cities sorted by name:
#    The'display_cities_sorted_by_name'function is similar to the previous one but sorts the cities alphabetically by name.
#
# 4. Display Total Population:
#    The'display_total_population'function calculates the total population of all cities by executing an SQL query with the SUM aggregate function on 'Population' Column. The result is then printed.
#
# 5. Display City with Highest Population:
#    The'Display_average_population'function calculates the average population of all cities using the AVG aggregate function in an SQL query. The average population is then printed.
#
# 6. Display City with Highest Population:
#    The'display_city_with_highest_population'function retrieves the city with the highest population by executing an SQL query that sorts the cities in descending order of population and limits the result to the first row. The city with the highest population is then printed.
#
# 7. Display City with Lowest Population:
#    The'display_city_with_lowest_population'function is similar to the previous one but retrieves the city with the lowest population by sorting the cities in ascending order of population and limiting the result to first row. The city with the lowest population is then printed.
#
# 8. User Interaction Loop:
#    The'if __name__ == "__main__":'block is the entry point of the program. It includes a loop that repeatedly presents a menu of options to the user. The user can choose an operation by entering a corresponding number. The selected operation is then executed, and the loop continues until the user chooses to exit.
